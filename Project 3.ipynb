# %%
import time
import pandas as pd
import numpy as np

CITY_DATA = {'chicago': 'chicago.csv',
             'new york city': 'new_york_city.csv',
             'washington': 'washington.csv'}

def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!')
    while True:
        city = input("Would you like to see data for Chicago, New York City, or Washington?\n").lower()
        if city in CITY_DATA:
            break
        else:
            print("Invalid input. Please enter a valid city name.")

    while True:
        month = input("Which month would you like to filter by? January, February, March, April, May, or June? Type 'all' for no filter.\n").lower()
        if month in ['all', 'january', 'february', 'march', 'april', 'may', 'june']:
            break
        else:
            print("Invalid input. Please enter a valid month or 'all'.")

    while True:
        day = input("Which day of the week would you like to filter by? Monday, Tuesday, Wednesday, Thursday, Friday, Saturday, or Sunday? Type 'all' for no filter.\n").lower()
        if day in ['all', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']:
            break
        else:
            print("Invalid input. Please enter a valid day or 'all'.")

    print('-'*40)
    return city, month, day


def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """
    # Load data file into a dataframe
    df = pd.read_csv(CITY_DATA[city])

    # Convert the 'Start Time' column to datetime
    df['Start Time'] = pd.to_datetime(df['Start Time'])

    # Extract month and day of week from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['day_of_week'] = df['Start Time'].dt.day_name()

    # Filter by month if applicable
    if month != 'all':
        # Use the index of the months list to get the corresponding int
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1

        # Filter by month to create the new dataframe
        df = df[df['month'] == month]

    # Filter by day of week if applicable
    if day != 'all':
        # Filter by day of week to create the new dataframe
        df = df[df['day_of_week'] == day.title()]

    return df


def time_stats(df):
    """Displays statistics on the most frequent times of travel."""

    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()

    # Display the most common month
    popular_month = df['month'].mode()[0]
    print('Most Common Month:', popular_month)

    # Display the most common day of week
    popular_day = df['day_of_week'].mode()[0]
    print('Most Common Day of Week:', popular_day)

    # Display the most common start hour
    df['hour'] = df['Start Time'].dt.hour
    popular_hour = df['hour'].mode()[0]
    print('Most Common Start Hour:', popular_hour)

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # Display most commonly used start station
    popular_start_station = df['Start Station'].mode()[0]
    print('Most Commonly Used Start Station:', popular_start_station)

    # Display most commonly used end station
    popular_end_station = df['End Station'].mode()[0]
    print('Most Commonly Used End Station:', popular_end_station)

    # Display most frequent combination of start station and end station trip
    df['Trip'] = df['Start Station'] + ' to ' + df['End Station']
    popular_trip = df['Trip'].mode()[0]
    print('Most Frequent Trip:', popular_trip)

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # Display total travel time
    total_travel_time = df['Trip Duration'].sum()
    print('Total Travel Time:', total_travel_time)

    # Display mean travel time
    mean_travel_time = df['Trip Duration'].mean()
    print('Mean Travel Time:', mean_travel_time)

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def user_stats(df):
    """Displays statistics on bikeshare users."""

    print('\nCalculating User Stats...\n')
    start_time = time.time()

    # Display counts of user types
    user_types = df['User Type'].value_counts()
    print('Counts of User Types:')
    print(user_types)

    # Display counts of gender if available
    if 'Gender' in df.columns:
        gender_counts = df['Gender'].value_counts()
        print('\nCounts of Gender:')
        print(gender_counts)
    else:
        print('\nGender data not available for this city.')

    # Display earliest, most recent, and most common year of birth if available
    if 'Birth Year' in df.columns:
        earliest_birth_year = int(df['Birth Year'].min())
        most_recent_birth_year = int(df['Birth Year'].max())
        most_common_birth_year = int(df['Birth Year'].mode()[0])
        print('\nEarliest Birth Year:', earliest_birth_year)
        print('Most Recent Birth Year:', most_recent_birth_year)
        print('Most Common Birth Year:', most_common_birth_year)
    else:
        print('\nBirth year data not available for this city.')

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def display_data(df):
    """
    Display raw data upon request by the user.

    Args:
        df (DataFrame): Pandas DataFrame containing the data to be displayed.
    """
    view_data = input("Would you like to view 5 rows of individual trip data? Enter yes or no?\n")
    start_loc = 0
    while view_data.lower() == 'yes':
        print(df.iloc[start_loc:start_loc + 5])
        start_loc += 5
        view_data = input("Do you wish to continue with the next 5 rows?: ").lower()

        if view_data.lower() != 'yes':
            break
    else:
        print("There is no more data to display.")


def main():
    while True:
        city, month, day = get_filters()
        df = load_data(city, month, day)

        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df)

        display_data(df)  # Add display_data function call here

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break


if __name__ == "__main__":
    main()
# Out:
# Hello! Let's explore some US bikeshare data!
# Would you like to see data for Chicago, New York City, or Washington?
# chicago
# Which month would you like to filter by? January, February, March, April, May, or June? Type 'all' for no filter.
# may
# Which day of the week would you like to filter by? Monday, Tuesday, Wednesday, Thursday, Friday, Saturday, or Sunday? Type 'all' for no filter.
# saturday
# ----------------------------------------
#
# Calculating The Most Frequent Times of Travel...
#
# Most Common Month: 5
# Most Common Day of Week: Saturday
# Most Common Start Hour: 15
#
# This took 0.0012018680572509766 seconds.
# ----------------------------------------
#
# Calculating The Most Popular Stations and Trip...
#
# Most Commonly Used Start Station: Streeter Dr & Grand Ave
# Most Commonly Used End Station: Streeter Dr & Grand Ave
# Most Frequent Trip: Lake Shore Dr & Monroe St to Streeter Dr & Grand Ave
#
# This took 0.0022242069244384766 seconds.
# ----------------------------------------
#
# Calculating Trip Duration...
#
# Total Travel Time: 10764712
# Mean Travel Time: 1266.8838413557726
#
# This took 9.107589721679688e-05 seconds.
# ----------------------------------------
#
# Calculating User Stats...
#
# Counts of User Types:
# User Type
# Subscriber    4690
# Customer      3807
# Name: count, dtype: int64
#
# Counts of Gender:
# Gender
# Male      3302
# Female    1389
# Name: count, dtype: int64
#
# Earliest Birth Year: 1899
# Most Recent Birth Year: 2001
# Most Common Birth Year: 1990
#
# This took 0.0012011528015136719 seconds.
# ----------------------------------------
# Would you like to view 5 rows of individual trip data? Enter yes or no?
# yes
#      Unnamed: 0          Start Time             End Time  Trip Duration  \
# 42       814960 2017-05-13 14:39:17  2017-05-13 14:40:40             83
# 106      748995 2017-05-06 20:28:25  2017-05-06 20:46:42           1097
# 161      746374 2017-05-06 15:36:10  2017-05-06 15:49:40            810
# 178      975576 2017-05-27 14:44:01  2017-05-27 14:48:17            256
# 203      812487 2017-05-13 12:53:59  2017-05-13 13:29:23           2124
#
#                  Start Station                 End Station   User Type Gender  \
# 42   Humphrey Ave & Ontario St   Humphrey Ave & Ontario St  Subscriber   Male
# 106     Clark St & Randolph St       Dearborn St & Erie St    Customer    NaN
# 161       McClurg Ct & Erie St  Lake Shore Dr & North Blvd  Subscriber   Male
# 178            Millennium Park             Millennium Park    Customer    NaN
# 203     St. Clair St & Erie St         Theater on the Lake    Customer    NaN
#
#      Birth Year  month day_of_week  hour  \
# 42       1987.0      5    Saturday    14
# 106         NaN      5    Saturday    20
# 161      1993.0      5    Saturday    15
# 178         NaN      5    Saturday    14
# 203         NaN      5    Saturday    12
#
#                                                   Trip
# 42   Humphrey Ave & Ontario St to Humphrey Ave & On...
# 106    Clark St & Randolph St to Dearborn St & Erie St
# 161  McClurg Ct & Erie St to Lake Shore Dr & North ...
# 178                 Millennium Park to Millennium Park
# 203      St. Clair St & Erie St to Theater on the Lake
# Do you wish to continue with the next 5 rows?: yes
#      Unnamed: 0          Start Time             End Time  Trip Duration  \
# 323      973156 2017-05-27 13:15:49  2017-05-27 13:53:11           2242
# 334      743340 2017-05-06 11:17:39  2017-05-06 11:24:23            404
# 353      973777 2017-05-27 13:38:54  2017-05-27 13:49:17            623
# 355      747402 2017-05-06 16:57:31  2017-05-06 18:19:30           4919
# 357      904012 2017-05-20 19:58:51  2017-05-20 20:28:51           1800
#
#                    Start Station                      End Station   User Type  \
# 323         Broadway & Barry Ave         Kingsbury St & Kinzie St  Subscriber
# 334  Winchester Ave & Elston Ave           Damen Ave & Pierce Ave    Customer
# 353      Orleans St & Elm St (*)        Bissell St & Armitage Ave  Subscriber
# 355               Shedd Aquarium          Franklin St & Monroe St    Customer
# 357      Streeter Dr & Grand Ave  Cityfront Plaza Dr & Pioneer Ct    Customer
#
#     Gender  Birth Year  month day_of_week  hour  \
# 323   Male      1990.0      5    Saturday    13
# 334    NaN         NaN      5    Saturday    11
# 353   Male      1991.0      5    Saturday    13
# 355    NaN         NaN      5    Saturday    16
# 357    NaN         NaN      5    Saturday    19
#
#                                                   Trip
# 323   Broadway & Barry Ave to Kingsbury St & Kinzie St
# 334  Winchester Ave & Elston Ave to Damen Ave & Pie...
# 353  Orleans St & Elm St (*) to Bissell St & Armita...
# 355          Shedd Aquarium to Franklin St & Monroe St
# 357  Streeter Dr & Grand Ave to Cityfront Plaza Dr ...
# Do you wish to continue with the next 5 rows?: yes
#      Unnamed: 0          Start Time             End Time  Trip Duration  \
# 373      811988 2017-05-13 12:30:43  2017-05-13 12:40:03            560
# 388      809604 2017-05-13 10:27:06  2017-05-13 10:45:11           1085
# 392      983602 2017-05-27 21:10:43  2017-05-27 21:15:52            309
# 472      974670 2017-05-27 14:10:04  2017-05-27 14:32:01           1317
# 474      979489 2017-05-27 17:05:26  2017-05-27 17:16:51            685
#
#                Start Station                   End Station   User Type  \
# 373    Wells St & Concord Ln     Cannon Dr & Fullerton Ave  Subscriber
# 388  Clinton St & Madison St        Michigan Ave & Lake St    Customer
# 392  Clark St & Armitage Ave     Bissell St & Armitage Ave  Subscriber
# 472    Dearborn St & Erie St  Southport Ave & Clybourn Ave    Customer
# 474      Morgan St & Lake St    Larrabee St & Kingsbury St  Subscriber
#
#      Gender  Birth Year  month day_of_week  hour  \
# 373    Male      1980.0      5    Saturday    12
# 388     NaN         NaN      5    Saturday    10
# 392  Female      1987.0      5    Saturday    21
# 472     NaN         NaN      5    Saturday    14
# 474  Female      1982.0      5    Saturday    17
#
#                                                   Trip
# 373  Wells St & Concord Ln to Cannon Dr & Fullerton...
# 388  Clinton St & Madison St to Michigan Ave & Lake St
# 392  Clark St & Armitage Ave to Bissell St & Armita...
# 472  Dearborn St & Erie St to Southport Ave & Clybo...
# 474  Morgan St & Lake St to Larrabee St & Kingsbury St
# Do you wish to continue with the next 5 rows?: no
#
# Would you like to restart? Enter yes or no.
# no
